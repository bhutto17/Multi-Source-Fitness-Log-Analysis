# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Install Kaggle API

# %%
# !pip install kaggle

# %% [markdown]
# Copy Kaggle API Key to .kaggle Directory

# %%
# !mkdir -p ~/.kaggle
# !cp "/content/drive/MyDrive/00000000_FIVERR/datanalyst_28/Faizan Bhutto Portfolio/kaggle_api_key/kaggle (3).json" ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Set Working Directory:

# %%
import os
os.chdir('/content/drive/MyDrive/00000000_FIVERR/datanalyst_28/Faizan Bhutto Portfolio/01 - Sports Logging Project')
# !pwd
# Out:
# /content/drive/MyDrive/00000000_FIVERR/datanalyst_28/Faizan Bhutto Portfolio/01 - Sports Logging Project

# %% [markdown]
# Create Data Folder

# %%
data_dir = 'Data'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %% [markdown]
# Download the Dataset

# %%
# !kaggle datasets download -d vlbthambawita/pmdata-a-sports-logging-dataset -p Data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vlbthambawita/pmdata-a-sports-logging-dataset
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
#  99% 1.30G/1.31G [00:25<00:00, 51.2MB/s]
# 100% 1.31G/1.31G [00:25<00:00, 54.6MB/s]

# %% [markdown]
# Unzip the Dataset

# %%
import zipfile
zip_path = 'Data/pmdata-a-sports-logging-dataset.zip'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('Data')

# %% [markdown]
# Delete the Original Zip File

# %%
zip_path = 'Data/pmdata-a-sports-logging-dataset.zip'

#if zip file exists, then delete it
if os.path.exists(zip_path):
    os.remove(zip_path)
    print(f"Deleted the zip file: {zip_path}")
else:
    print(f"The zip file does not exist: {zip_path}")
# Out:
# Deleted the zip file: Data/pmdata-a-sports-logging-dataset.zip
